# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/HousePriceBharatIntern.csv')

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# Price                                    0
# ...

# %%
df.head()
# Out:
#     Date  number of bedrooms  number of bathrooms  living area  lot area  \
# 0  42491                   5                 2.50         3650      9050
# 1  42491                   4                 2.50         2920      4000
# 2  42491                   5                 2.75         2910      9480
# 3  42491                   4                 2.50         3310     42998
# 4  42491                   3                 2.00         2710      4500
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# 3               2.0                   0                0
# 4               1.5                   0                0
#
#    condition of the house  grade of the house  ...  Built Year  \
# 0                       5                  10  ...        1921
# ...

# %%
df.drop('Date', axis=1, inplace=True)

# %%
df.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
# 3                   4                 2.50         3310     42998
# 4                   3                 2.00         2710      4500
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# 3               2.0                   0                0
# 4               1.5                   0                0
#
#    condition of the house  grade of the house  \
# 0                       5                  10
# 1                       5                   8
# 2                       3                   8
# ...

# %%
df.shape
# Out:
# (14620, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14620 non-null  int64
#  1   number of bathrooms                    14620 non-null  float64
#  2   living area                            14620 non-null  int64
#  3   lot area                               14620 non-null  int64
#  4   number of floors                       14620 non-null  float64
#  5   waterfront present                     14620 non-null  int64
#  6   number of views                        14620 non-null  int64
#  7   condition of the house                 14620 non-null  int64
#  8   grade of the house                     14620 non-null  int64
#  9   Area of the house(excluding basement)  14620 non-null  int64
# ...

# %%
df.describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        14620.000000         14620.000000  14620.000000  1.462000e+04
# mean             3.379343             2.129583   2098.262996  1.509328e+04
# std              0.938719             0.769934    928.275721  3.791962e+04
# min              1.000000             0.500000    370.000000  5.200000e+02
# 25%              3.000000             1.750000   1440.000000  5.010750e+03
# 50%              3.000000             2.250000   1930.000000  7.620000e+03
# 75%              4.000000             2.500000   2570.000000  1.080000e+04
# max             33.000000             8.000000  13540.000000  1.074218e+06
#
#        number of floors  waterfront present  number of views  \
# count      14620.000000        14620.000000     14620.000000
# mean           1.502360            0.007661         0.233105
# std            0.540239            0.087193         0.766259
# ...

# %%
df.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
# 3                   4                 2.50         3310     42998
# 4                   3                 2.00         2710      4500
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# 3               2.0                   0                0
# 4               1.5                   0                0
#
#    condition of the house  grade of the house  \
# 0                       5                  10
# 1                       5                   8
# 2                       3                   8
# ...

# %%
df.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df = df.rename(columns={'number of bedrooms': 'no_of_bedrooms', 'number of bathrooms': 'no_of_bathrooms', 'living area': 'living_area', 'lot area':'plot_area', 'number of floors': 'no_of_floors', 'Area of the house(excluding basement)': 'area_of_house_excludingbasement', 'Distance from the airport':'distance_from_airport', 'Number of schools nearby' : 'no_of_schools_nearby'})

# %%
df.columns
# Out:
# Index(['no_of_bedrooms', 'no_of_bathrooms', 'living_area', 'plot_area',
#        'no_of_floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'area_of_house_excludingbasement', 'Area of the basement', 'Built Year',
#        'Renovation Year', 'Postal Code', 'Lattitude', 'Longitude',
#        'living_area_renov', 'lot_area_renov', 'no_of_schools_nearby',
#        'distance_from_airport', 'Price'],
#       dtype='object')

# %%
df['no_of_bathrooms'] = df['no_of_bathrooms'].astype(int)

# %%
df['no_of_floors'] = df['no_of_floors'].astype(int)

# %%
df.head()
# Out:
#    no_of_bedrooms  no_of_bathrooms  living_area  plot_area  no_of_floors  \
# 0               5                2         3650       9050             2
# 1               4                2         2920       4000             1
# 2               5                2         2910       9480             1
# 3               4                2         3310      42998             2
# 4               3                2         2710       4500             1
#
#    waterfront present  number of views  condition of the house  \
# 0                   0                4                       5
# 1                   0                0                       5
# 2                   0                0                       3
# 3                   0                0                       3
# 4                   0                0                       4
#
#    grade of the house  area_of_house_excludingbasement  ...  Built Year  \
# ...

# %%
df.columns
# Out:
# Index(['no_of_bedrooms', 'no_of_bathrooms', 'living_area', 'plot_area',
#        'no_of_floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'area_of_house_excludingbasement', 'Area of the basement', 'Built Year',
#        'Renovation Year', 'Postal Code', 'Lattitude', 'Longitude',
#        'living_area_renov', 'lot_area_renov', 'no_of_schools_nearby',
#        'distance_from_airport', 'Price'],
#       dtype='object')

# %%
df.drop('waterfront present', axis=1, inplace=True)

# %%
df.drop('number of views', axis=1, inplace=True)

# %%
df.drop('condition of the house', axis=1, inplace=True)

# %%
df.drop('Postal Code', axis=1, inplace=True)

# %%
df.drop('living_area_renov', axis=1, inplace=True)

# %%
df.drop('lot_area_renov', axis=1, inplace=True)

# %%
df.head()
# Out:
#    no_of_bedrooms  no_of_bathrooms  living_area  plot_area  no_of_floors  \
# 0               5                2         3650       9050             2
# 1               4                2         2920       4000             1
# 2               5                2         2910       9480             1
# 3               4                2         3310      42998             2
# 4               3                2         2710       4500             1
#
#    grade of the house  area_of_house_excludingbasement  Area of the basement  \
# 0                  10                             3370                   280
# 1                   8                             1910                  1010
# 2                   8                             2910                     0
# 3                   9                             3310                     0
# 4                   8                             1880                   830
#
# ...

# %%
df.drop('Built Year', axis=1, inplace=True)

# %%
df.drop('Renovation Year', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['no_of_bedrooms', 'no_of_bathrooms', 'living_area', 'plot_area',
#        'no_of_floors', 'grade of the house', 'area_of_house_excludingbasement',
#        'Area of the basement', 'Lattitude', 'Longitude',
#        'no_of_schools_nearby', 'distance_from_airport', 'Price'],
#       dtype='object')

# %%
import seaborn as sns
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(df.corr() , annot=True)
# Out:
# <Axes: >

# %%
import folium

# %%
from folium.plugins import HeatMap
import folium

# %%
map = folium.Map()
HeatMap(zip(list(df.Lattitude), list(df.Longitude))).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
X = df.drop('Price', axis=1)
y = np.log(df['Price'])

# %%
print(X)
# Out:
#        no_of_bedrooms  no_of_bathrooms  living_area  plot_area  no_of_floors  \
# 0                   5                2         3650       9050             2
# 1                   4                2         2920       4000             1
# 2                   5                2         2910       9480             1
# 3                   4                2         3310      42998             2
# 4                   3                2         2710       4500             1
# ...               ...              ...          ...        ...           ...
# 14615               2                1         1556      20000             1
# 14616               3                2         1680       7000             1
# 14617               2                1         1070       6120             1
# 14618               4                1         1030       6621             1
# 14619               3                1          900       4770             1
#
# ...

# %%
print(y)
# Out:
# 0        14.682611
# 1        14.151983
# 2        13.997832
# 3        13.638773
# 4        13.598598
#            ...
# 14615    12.309080
# 14616    12.297740
# 14617    12.250090
# 14618    12.230765
# 14619    11.891362
# Name: Price, Length: 14620, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %%
degree = 2
lin_reg = make_pipeline(PolynomialFeatures(degree), LinearRegression())
lin_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = lin_reg.predict(X_train)

# %%
error_score = r2_score(y_train, y_pred)
print("R squared Error : {:.2f}%".format(error_score*100))
# Out:
# R squared Error : 77.47%

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x=y_pred,y=y_train)
plt.xlabel("predicted price")
plt.ylabel("actual price")
# Out:
# Text(0, 0.5, 'actual price')

# %%
#will improve the outliers later
